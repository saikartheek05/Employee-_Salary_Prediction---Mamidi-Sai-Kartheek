# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mamid\Downloads\adult_modified_with_names.csv")

# %%
df
# Out:
#        Age     workclass  fnlwgt Qualification  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  Hours/Week native-country income  \
# 0                 0             0          40  United-States  <=50K
# 1                 0             0          50  United-States  <=50K
# 2                 0             0          40  United-States   >50K
# 3              7688             0          40  United-States   >50K
# 4                 0             0          30  United-States  <=50K
# ...             ...           ...         ...            ...    ...
# 48837             0             0          38  United-States  <=50K
# 48838             0             0          40  United-States   >50K
# 48839             0             0          40  United-States  <=50K
# 48840             0             0          20  United-States  <=50K
# 48841         15024             0          40  United-States   >50K
#
#                 Name               Job Role  Experience
# 0          David Kim  Systems Administrator          13
# 1         Sara Patel      Software Engineer           7
# 2        Emily Davis           Data Analyst           9
# 3        Michael Lee        Project Manager           7
# 4        Emily Davis          HR Specialist          11
# ...              ...                    ...         ...
# 48837      David Kim       Technical Writer          23
# 48838    Michael Lee  Systems Administrator          29
# 48839    Emily Davis          HR Specialist          26
# 48840      David Kim          HR Specialist          25
# 48841  Alice Johnson           Data Analyst           7
#
# [48842 rows x 18 columns]

# %%
df.head()
# Out:
#    Age  workclass  fnlwgt Qualification  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    Hours/Week native-country income         Name               Job Role  \
# 0          40  United-States  <=50K    David Kim  Systems Administrator
# 1          50  United-States  <=50K   Sara Patel      Software Engineer
# 2          40  United-States   >50K  Emily Davis           Data Analyst
# 3          40  United-States   >50K  Michael Lee        Project Manager
# 4          30  United-States  <=50K  Emily Davis          HR Specialist
#
#    Experience
# 0          13
# 1           7
# 2           9
# 3           7
# 4          11

# %%
df.tail()
# Out:
#        Age     workclass  fnlwgt Qualification  educational-num  \
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  Hours/Week native-country income  \
# 48837             0             0          38  United-States  <=50K
# 48838             0             0          40  United-States   >50K
# 48839             0             0          40  United-States  <=50K
# 48840             0             0          20  United-States  <=50K
# 48841         15024             0          40  United-States   >50K
#
#                 Name               Job Role  Experience
# 48837      David Kim       Technical Writer          23
# 48838    Michael Lee  Systems Administrator          29
# 48839    Emily Davis          HR Specialist          26
# 48840      David Kim          HR Specialist          25
# 48841  Alice Johnson           Data Analyst           7

# %%
df.shape
# Out:
# (48842, 18)

# %%
df.isna()
# Out:
#          Age  workclass  fnlwgt  Qualification  educational-num  \
# 0      False      False   False          False            False
# 1      False      False   False          False            False
# 2      False      False   False          False            False
# 3      False      False   False          False            False
# 4      False      False   False          False            False
# ...      ...        ...     ...            ...              ...
# 48837  False      False   False          False            False
# 48838  False      False   False          False            False
# 48839  False      False   False          False            False
# 48840  False      False   False          False            False
# 48841  False      False   False          False            False
#
#        marital-status  occupation  relationship   race  gender  capital-gain  \
# 0               False       False         False  False   False         False
# 1               False       False         False  False   False         False
# 2               False       False         False  False   False         False
# 3               False       False         False  False   False         False
# 4               False       False         False  False   False         False
# ...               ...         ...           ...    ...     ...           ...
# 48837           False       False         False  False   False         False
# 48838           False       False         False  False   False         False
# 48839           False       False         False  False   False         False
# 48840           False       False         False  False   False         False
# 48841           False       False         False  False   False         False
#
#        capital-loss  Hours/Week  native-country  income   Name  Job Role  \
# 0             False       False           False   False  False     False
# 1             False       False           False   False  False     False
# 2             False       False           False   False  False     False
# 3             False       False           False   False  False     False
# 4             False       False           False   False  False     False
# ...             ...         ...             ...     ...    ...       ...
# 48837         False       False           False   False  False     False
# 48838         False       False           False   False  False     False
# 48839         False       False           False   False  False     False
# 48840         False       False           False   False  False     False
# 48841         False       False           False   False  False     False
#
#        Experience
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 48837       False
# 48838       False
# 48839       False
# 48840       False
# 48841       False
#
# [48842 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# Age                0
# workclass          0
# fnlwgt             0
# Qualification      0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# Hours/Week         0
# native-country     0
# income             0
# Name               0
# Job Role           0
# Experience         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   Qualification    48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  Hours/Week       48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
#  15  Name             48842 non-null  object
#  16  Job Role         48842 non-null  object
#  17  Experience       48842 non-null  int64
# dtypes: int64(7), object(11)
# memory usage: 6.7+ MB

# %%
print(df['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
print(df['Qualification'].value_counts())
# Out:
# Qualification
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
print(df['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
print(df['occupation'].value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(df['relationship'].value_counts())
# Out:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
print(df['race'].value_counts())
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(df['native-country'].value_counts())
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Thailand                         30
# Hong                             30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Outlying-US(Guam-USVI-etc)       23
# Yugoslavia                       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
df['workclass'].replace({"?" : "others"}, inplace=True)
# Out:
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\645791497.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['workclass'].replace({"?" : "others"}, inplace=True)

# %%
print(df['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['occupation'].replace({"?" : "others"}, inplace=True)
# Out:
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\718025694.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['occupation'].replace({"?" : "others"}, inplace=True)

# %%
print(df['occupation'].value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['native-country'].replace({"?" : "others"}, inplace=True)
# Out:
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\2486937244.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['native-country'].replace({"?" : "others"}, inplace=True)

# %%
print(df['native-country'].value_counts())
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# others                          857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Thailand                         30
# Hong                             30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Outlying-US(Guam-USVI-etc)       23
# Yugoslavia                       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
df = df[df['workclass'] != 'Without-pay']
df = df[df['workclass'] != 'Never-worked']

# %%
print(df['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
df = df[df['Qualification'] != '5th-6th']
df = df[df['Qualification'] != '1st-4th']
df = df[df['Qualification'] != 'Preschool']

# %%
print(df['Qualification'].value_counts())
# Out:
# Qualification
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# Name: count, dtype: int64

# %%
df = df[df['occupation'] != 'Priv-house-serv']
df = df[df['occupation'] != 'Armed-Forces']

# %%
print(df['occupation'].value_counts())
# Out:
# occupation
# Prof-specialty       6165
# Exec-managerial      6072
# Craft-repair         6006
# Adm-clerical         5591
# Sales                5476
# Other-service        4746
# Machine-op-inspct    2877
# others               2730
# Transport-moving     2302
# Handlers-cleaners    1980
# Tech-support         1445
# Farming-fishing      1380
# Protective-serv       981
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (47751, 18)

# %%
df.drop(columns=['educational-num'], inplace=True)

# %%
df
# Out:
#        Age     workclass  fnlwgt Qualification      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18        others  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# 2        Protective-serv      Husband  White    Male             0
# 3      Machine-op-inspct      Husband  Black    Male          7688
# 4                 others    Own-child  White  Female             0
# ...                  ...          ...    ...     ...           ...
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  Hours/Week native-country income           Name  \
# 0                 0          40  United-States  <=50K      David Kim
# 1                 0          50  United-States  <=50K     Sara Patel
# 2                 0          40  United-States   >50K    Emily Davis
# 3                 0          40  United-States   >50K    Michael Lee
# 4                 0          30  United-States  <=50K    Emily Davis
# ...             ...         ...            ...    ...            ...
# 48837             0          38  United-States  <=50K      David Kim
# 48838             0          40  United-States   >50K    Michael Lee
# 48839             0          40  United-States  <=50K    Emily Davis
# 48840             0          20  United-States  <=50K      David Kim
# 48841             0          40  United-States   >50K  Alice Johnson
#
#                     Job Role  Experience
# 0      Systems Administrator          13
# 1          Software Engineer           7
# 2               Data Analyst           9
# 3            Project Manager           7
# 4              HR Specialist          11
# ...                      ...         ...
# 48837       Technical Writer          23
# 48838  Systems Administrator          29
# 48839          HR Specialist          26
# 48840          HR Specialist          25
# 48841           Data Analyst           7
#
# [47751 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Age'])
plt.grid(True)
plt.show()

# %%
df = df[(df['Age'] >= 15) & (df['Age'] < 75)]

# %%
plt.boxplot(df['Age'])
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['workclass'] = encoder.fit_transform(df['workclass'])
df['fnlwgt'] = encoder.fit_transform(df['fnlwgt'])
df['Qualification'] = encoder.fit_transform(df['Qualification'])
df['marital-status'] = encoder.fit_transform(df['marital-status'])
df['occupation'] = encoder.fit_transform(df['occupation'])
df['relationship'] = encoder.fit_transform(df['relationship'])
df['race'] = encoder.fit_transform(df['race'])
df['gender'] = encoder.fit_transform(df['gender'])
df['capital-loss'] = encoder.fit_transform(df['capital-loss'])
df['capital-gain'] = encoder.fit_transform(df['capital-gain'])
df['native-country'] = encoder.fit_transform(df['native-country'])
df
# Out:
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['workclass'] = encoder.fit_transform(df['workclass'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fnlwgt'] = encoder.fit_transform(df['fnlwgt'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Qualification'] = encoder.fit_transform(df['Qualification'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marital-status'] = encoder.fit_transform(df['marital-status'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['occupation'] = encoder.fit_transform(df['occupation'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['relationship'] = encoder.fit_transform(df['relationship'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race'] = encoder.fit_transform(df['race'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = encoder.fit_transform(df['gender'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['capital-loss'] = encoder.fit_transform(df['capital-loss'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['capital-gain'] = encoder.fit_transform(df['capital-gain'])
# C:\Users\mamid\AppData\Local\Temp\ipykernel_23608\721500056.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['native-country'] = encoder.fit_transform(df['native-country'])
#        Age  workclass  fnlwgt  Qualification  marital-status  occupation  \
# 0       25          2   18769              1               4           5
# 1       38          2    4088              9               2           3
# 2       28          1   24581              5               2           8
# 3       44          2   10851             12               2           5
# 4       18          6    5241             12               4          12
# ...    ...        ...     ...            ...             ...         ...
# 48837   27          2   20933              5               2          10
# 48838   40          2   10249              9               2           5
# 48839   58          2    9993              9               6           0
# 48840   22          2   16326              9               4           0
# 48841   52          3   22630              9               2           2
#
#        relationship  race  gender  capital-gain  capital-loss  Hours/Week  \
# 0                 3     2       1             0             0          40
# 1                 0     4       1             0             0          50
# 2                 0     4       1             0             0          40
# 3                 0     2       1            96             0          40
# 4                 3     4       0             0             0          30
# ...             ...   ...     ...           ...           ...         ...
# 48837             5     4       0             0             0          38
# 48838             0     4       1             0             0          40
# 48839             4     4       0             0             0          40
# 48840             3     4       1             0             0          20
# 48841             5     4       0           110             0          40
#
#        native-country income           Name               Job Role  Experience
# 0                  38  <=50K      David Kim  Systems Administrator          13
# 1                  38  <=50K     Sara Patel      Software Engineer           7
# 2                  38   >50K    Emily Davis           Data Analyst           9
# 3                  38   >50K    Michael Lee        Project Manager           7
# 4                  38  <=50K    Emily Davis          HR Specialist          11
# ...               ...    ...            ...                    ...         ...
# 48837              38  <=50K      David Kim       Technical Writer          23
# 48838              38   >50K    Michael Lee  Systems Administrator          29
# 48839              38  <=50K    Emily Davis          HR Specialist          26
# 48840              38  <=50K      David Kim          HR Specialist          25
# 48841              38   >50K  Alice Johnson           Data Analyst           7
#
# [47340 rows x 17 columns]

# %%
x = df.drop(columns=['income'])
y = df['income']

# %%
x
# Out:
#        Age  workclass  fnlwgt  Qualification  marital-status  occupation  \
# 0       25          2   18769              1               4           5
# 1       38          2    4088              9               2           3
# 2       28          1   24581              5               2           8
# 3       44          2   10851             12               2           5
# 4       18          6    5241             12               4          12
# ...    ...        ...     ...            ...             ...         ...
# 48837   27          2   20933              5               2          10
# 48838   40          2   10249              9               2           5
# 48839   58          2    9993              9               6           0
# 48840   22          2   16326              9               4           0
# 48841   52          3   22630              9               2           2
#
#        relationship  race  gender  capital-gain  capital-loss  Hours/Week  \
# 0                 3     2       1             0             0          40
# 1                 0     4       1             0             0          50
# 2                 0     4       1             0             0          40
# 3                 0     2       1            96             0          40
# 4                 3     4       0             0             0          30
# ...             ...   ...     ...           ...           ...         ...
# 48837             5     4       0             0             0          38
# 48838             0     4       1             0             0          40
# 48839             4     4       0             0             0          40
# 48840             3     4       1             0             0          20
# 48841             5     4       0           110             0          40
#
#        native-country           Name               Job Role  Experience
# 0                  38      David Kim  Systems Administrator          13
# 1                  38     Sara Patel      Software Engineer           7
# 2                  38    Emily Davis           Data Analyst           9
# 3                  38    Michael Lee        Project Manager           7
# 4                  38    Emily Davis          HR Specialist          11
# ...               ...            ...                    ...         ...
# 48837              38      David Kim       Technical Writer          23
# 48838              38    Michael Lee  Systems Administrator          29
# 48839              38    Emily Davis          HR Specialist          26
# 48840              38      David Kim          HR Specialist          25
# 48841              38  Alice Johnson           Data Analyst           7
#
# [47340 rows x 16 columns]

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 47340, dtype: object

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\mamid\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\mamid\appdata\roaming\python\python313\site-packages (from xgboost) (2.3.1)
# Requirement already satisfied: scipy in c:\users\mamid\appdata\roaming\python\python313\site-packages (from xgboost) (1.16.0)

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score,confusion_matrix
from sklearn.preprocessing import LabelEncoder

noise = ['workclass', 'fnlwgt', 'Qualification', 'marital-status','occupation', 'relationship', 'race', 'gender','capital-gain', 'Hours/Week', 'native-country','Name', 'Job Role', 'Experience']

x_cleaned = x.drop(columns=noise)

x_train,x_test,y_train,y_test = train_test_split(x_cleaned, y, random_state=42, test_size=0.2, stratify=y)

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

model = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1, random_state=42, eval_metric='logloss')
model.fit(x_train, y_train_enc)
predictions = model.predict(x_test)
predicted_lables = le.inverse_transform(predictions)

accuracy = accuracy_score(y_test_enc, predictions)
print(f"Accuracy score is: {accuracy: .2f}")

f1_score = f1_score(y_test_enc, predictions, average=None)
print("the f1 score is", f1_score)

confusion_matrix = confusion_matrix(y_test_enc, predictions)
print("the confusion matrix is", confusion_matrix)

result = pd.DataFrame({
    "Age": x_test['Age'],
    "predictedIncome":le.inverse_transform(predictions)
})
result.to_csv('employee_salary_prediction.csv', index=False)
print(result)

plotting = result.groupby(['Age', 'predictedIncome']).size().unstack(fill_value=0)
plt.figure(figsize=(8, 6))
plotting.plot(kind='line', marker='*', colormap='coolwarm')
plt.xlabel("Age")
plt.ylabel("income")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Accuracy score is:  0.78
# the f1 score is [0.87238072 0.18620958]
# the confusion matrix is [[7140   14]
#  [2075  239]]
#        Age predictedIncome
# 43268   37           <=50K
# 31250   59           <=50K
# 13068   33           <=50K
# 29865   25           <=50K
# 13007   38           <=50K
# ...    ...             ...
# 7862    51           <=50K
# 4714    55           <=50K
# 15512   35           <=50K
# 45198   46           <=50K
# 39364   42           <=50K
#
# [9468 rows x 2 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9468 entries, 43268 to 39364
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              9468 non-null   int64
#  1   predictedIncome  9468 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 221.9+ KB

# %%
result
# Out:
#        Age predictedIncome
# 43268   37           <=50K
# 31250   59           <=50K
# 13068   33           <=50K
# 29865   25           <=50K
# 13007   38           <=50K
# ...    ...             ...
# 7862    51           <=50K
# 4714    55           <=50K
# 15512   35           <=50K
# 45198   46           <=50K
# 39364   42           <=50K
#
# [9468 rows x 2 columns]

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\mamid\anaconda3\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: packaging<25,>=20 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\mamid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mamid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\mamid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in c:\users\mamid\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mamid\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mamid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mamid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mamid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mamid\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\mamid\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mamid\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install streamlit_jupyter
# Out:
# Requirement already satisfied: streamlit_jupyter in c:\users\mamid\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: fastcore in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (1.8.5)
# Requirement already satisfied: ipywidgets==7.7.2 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (7.7.2)
# Requirement already satisfied: jupyter in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (1.1.1)
# Requirement already satisfied: stqdm in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (0.0.5)
# Requirement already satisfied: streamlit>=1.19 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (1.45.1)
# Requirement already satisfied: tabulate in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (0.9.0)
# Requirement already satisfied: tqdm in c:\users\mamid\anaconda3\lib\site-packages (from streamlit_jupyter) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (6.29.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (8.30.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\mamid\anaconda3\lib\site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (1.1.11)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mamid\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (7.3.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.8.11)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (24.2)
# Requirement already satisfied: psutil in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\mamid\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (6.5.1)
# Requirement already satisfied: decorator in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\mamid\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\mamid\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\mamid\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (308)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\mamid\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\mamid\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in c:\users\mamid\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\mamid\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (72.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\mamid\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\mamid\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mamid\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mamid\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\mamid\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\mamid\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\mamid\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mamid\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\mamid\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.1)
# Requirement already satisfied: uri-template in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\mamid\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\mamid\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mamid\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\mamid\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\mamid\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mamid\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\mamid\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mamid\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mamid\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.3.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit>=1.19->streamlit_jupyter) (2.3.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit>=1.19->streamlit_jupyter) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from streamlit>=1.19->streamlit_jupyter) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (19.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mamid\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit_jupyter) (3.1.43)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\mamid\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (4.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit_jupyter) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mamid\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit_jupyter) (2025.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mamid\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\mamid\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mamid\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\mamid\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit_jupyter) (1.3.0)
# Requirement already satisfied: jupyter-console in c:\users\mamid\anaconda3\lib\site-packages (from jupyter->streamlit_jupyter) (6.6.3)
# Requirement already satisfied: executing in c:\users\mamid\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\mamid\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\mamid\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import numpy as np

st.markdown(
    """
    <style>
    .stApp {
        background-image: url('https://images.unsplash.com/photo-1506744038136-46273834b3fb');
        background-size: cover;
        background-repeat: no-repeat;
        background-attachment: fixed;
    }
    </style>
    """,
    unsafe_allow_html=True
)

st.set_page_config(page_title='Employee Salary Prediction', layout='wide')

st.sidebar.header("User Input")

qualification = st.sidebar.selectbox(
    "Qualification",
    ["Choose an option", "Graduate", "Post-Graduate", "PhD"],
    index=0
)

age = st.sidebar.slider("Age", min_value=18, max_value=65, value=25)

name = st.sidebar.text_input("Name:", placeholder="Enter candidate name...")

job_role = st.sidebar.text_input("Job role:", placeholder="Enter job role...")

hour_per_week = st.sidebar.slider("Hours per week", 20, 80, 40)

experience = st.sidebar.slider("Years of experience", 0, 47, 5)

sidebar_predict = st.sidebar.button("Predict")

st.title("Employee Salary Prediction")

table_cols = ["Name", "Age", "Qualification", "Job Role", "Hours/Week", "Experience", "Predicted Salary"]
result_placeholder = st.empty()

def predict_salary(features):
    base = 20000 + features['experience'] * 1000 + features['age'] * 200 + features['hour_per_week'] * 40
    if features['qualification'] == "Post-Graduate":
        base += 8000
    if features['qualification'] == "PhD":
        base += 18000
    if "manager" in features['job_role'].lower():
        base += 10000
    if "data" in features['job_role'].lower():
        base += 8000
    return int(base // 100) * 100  

if sidebar_predict and qualification != "Choose an option":
    features = {
        "name": name,
        "age": age,
        "qualification": qualification,
        "job_role": job_role,
        "hour_per_week": hour_per_week,
        "experience": experience
    }
    pred_salary = predict_salary(features)
    df_display = pd.DataFrame([[
        features["name"], features["age"], features["qualification"],
        features["job_role"], features["hour_per_week"], features["experience"],
        f"${pred_salary:,.0f}"
    ]], columns=table_cols)
    result_placeholder.table(df_display)
elif sidebar_predict and qualification == "Choose an option":
    st.warning("Please select a valid qualification.")

st.subheader("Batch Prediction")
uploaded_file = st.file_uploader("Choose CSV file (columns: Name, Age, Qualification, Job Role, Hours/Week, Experience)", type=["csv"])
file_predict = st.button('Predict on File')

batch_graph_placeholder = st.empty()
batch_result_placeholder = st.empty()

if file_predict and uploaded_file is not None:
    df_in = pd.read_csv(uploaded_file)
    # Ensure column names match expectation
    required_cols = {"Name", "Age", "Qualification", "Job Role", "Hours/Week", "Experience"}
    if not required_cols.issubset(df_in.columns):
        st.error(f"Uploaded file missing one or more required columns: {required_cols}")
    else:
        results = []
        for _, row in df_in.iterrows():
            features = {
                "name": row.get("Name",""),
                "age": int(row.get("Age", 0)),
                "qualification": row.get("Qualification","Graduate"),
                "job_role": row.get("Job Role",""),
                "hour_per_week": int(row.get("Hours/Week", 0)),
                "experience": int(row.get("Experience", 0)),
            }
            pred_sal = predict_salary(features)
            results.append({
                "Name": features["name"],
                "Age": features["age"],
                "Qualification": features["qualification"],
                "Job Role": features["job_role"],
                "Hours/Week": features["hour_per_week"],
                "Experience": features["experience"],
                "Predicted Salary": pred_sal
            })
        df_out = pd.DataFrame(results)
        batch_result_placeholder.table(df_out)
        batch_graph_placeholder.line_chart(df_out[["Predicted Salary"]])

elif file_predict and uploaded_file is None:
    st.warning("Please upload a CSV file for batch prediction.")

st.markdown("""
*Instructions:*  
- Use the sidebar to enter employee details and predict a single salary.  
- To predict salaries for many people at once, upload a CSV with columns:  
  Name, Age, Qualification, Job Role, Hours/Week, Experience.
  Then click 'Predict on File'.  
- At right/below, you will see a graph and a table of predicted salaries.
""")
# Out:
# Overwriting app.py
